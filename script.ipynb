# %%
# !python C:/Users/Yashmitha/Desktop/Proj_cv/bloodcell/yolov5/detect.py --weights C:/Users/Yashmitha/Desktop/Proj_cv/bloodcell/yolov5/bestt.pt --source 0
# Out:
# detect: weights=['C:/Users/Yashmitha/Desktop/Proj_cv/bloodcell/yolov5/bestt.pt'], source=0, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-226-gdd9e338 Python-3.11.5 torch-2.1.0+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 6 RBCs, 2 WBCs, 1 platelets, 143.7ms
# 0: 480x640 6 RBCs, 2 WBCs, 119.7ms
# 0: 480x640 6 RBCs, 2 WBCs, 110.1ms
# 0: 480x640 6 RBCs, 2 WBCs, 114.5ms
# 0: 480x640 7 RBCs, 3 WBCs, 119.4ms
# 0: 480x640 7 RBCs, 1 WBC, 102.9ms
# 0: 480x640 5 RBCs, 1 WBC, 127.3ms
# ...
